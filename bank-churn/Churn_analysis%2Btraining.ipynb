// %% [markdown]
// # Add brunel  jar

// %%
%AddJar -magic https://brunelvis.org/jar/spark-kernel-brunel-all-2.3.jar -f
// Out:
// Starting download from https://brunelvis.org/jar/spark-kernel-brunel-all-2.3.jar
// Finished download of spark-kernel-brunel-all-2.3.jar

// %% [markdown]
// # Analysis of customer churn rate
// ## 1.1 Load data of customer churn rate

// %%
val churnDataRate = spark.read.format("jdbc").options(Map("driver" -> "com.ibm.db2.jcc.DB2Driver",
      "url" -> "jdbc:db2://9.125.72.72:430/LOCDB11", "user" -> "TUSER01",
      "password" -> "C6DESHOP", "dbtable" -> "MLZ.CHURN_RATE")).load()   
churnDataRate.show(5, false)
churnDataRate.count()
// Out:
// +----+-------+------------+----------+
// |Year|Quarter|Quarter_Year|Churn_Rate|
// +----+-------+------------+----------+
// |2014|1      |1Q14        |18.1      |
// |2014|2      |2Q14        |18.7      |
// |2014|3      |3Q14        |19.3      |
// |2014|4      |4Q14        |19.9      |
// |2015|1      |1Q15        |20.5      |
// +----+-------+------------+----------+
// only showing top 5 rows
// 12

// %% [markdown]
// ## 1.2 Drawing with the year as the X axis, the churn rate for the vertical

// %%
%%brunel data('churnDataRate') x(QUARTER_YEAR) y(CHURN_RATE) bar tooltip(#all) sort(YEAR:ascending, QUARTER:ascending) tooltip(#all) axes(x:'Time', y:'Churn Rate':grid) 
:: width=800, height=500
// Out:
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/brunel.2.3.css" charset="utf-8">
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/sumoselect.css" charset="utf-8">
//          <style>  </style>
//          <div id="controlsIde08bbe47-f14d-4cbb-b863-fb9df4057aa5" class="brunel"/>
// <svg id="visidf281a110-9b19-4cb3-b18e-1e11ea7d3f38" width="800" height="500"></svg>
//
// <script>
// require.config({
//             waitSeconds: 60,
//             paths: {
//                 'd3': '//cdnjs.cloudflare.com/ajax/libs/d3/4.2.1/d3.min',
//                 'topojson' : '//cdnjs.cloudflare.com/ajax/libs/topojson/1.6.20/topojson.min',
//                 'brunel' : 'https://brunelvis.org/js/brunel.2.3.min',
//                 'brunelControls' : 'https://brunelvis.org/js/brunel.controls.2.3.min'
//             },
//
//             shim: {
//                'brunel' : {
//                     exports: 'BrunelD3',
//                     deps: ['d3', 'topojson'],
//                     init: function() {
//                        return {
//                          BrunelD3 : BrunelD3,
//                          BrunelData : BrunelData
//                       }
//                     }
//                 },
//                'brunelControls' : {
//                     exports: 'BrunelEventHandlers',
//                     init: function() {
//                        return {
//                          BrunelEventHandlers: BrunelEventHandlers,
//                          BrunelJQueryControlFactory: BrunelJQueryControlFactory
//                       }
//                     }
//                 }
//
//             }
//
//         });
//
//         require(["d3"], function(d3) {
//         require(["brunel", "brunelControls"], function(brunel, brunelControls) {
//
//             function  BrunelVis(visId) {
//   "use strict";                                                                       // strict mode
//   var datasets = [],                                      // array of datasets for the original data
//       pre = function(d, i) { return d },                         // default pre-process does nothing
//       post = function(d, i) { return d },                       // default post-process does nothing
//       transitionTime = 200,                                        // transition time for animations
//       charts = [],                                                       // the charts in the system
//       vis = d3.select('#' + visId).attr('class', 'brunel');                     // the SVG container
//
//   BrunelD3.addDefinitions(vis);                                   // ensure standard symbols present
//
//   // Define chart #1 in the visualization //////////////////////////////////////////////////////////
//
//   charts[0] = function(parentNode, filterRows) {
//     var geom = BrunelD3.geometry(parentNode || vis.node(), 0, 0, 1, 1, 5, 43, 37, 0),
//       elements = [];                                              // array of elements in this chart
//
//     // Define groups for the chart parts ///////////////////////////////////////////////////////////
//
//     var chart =  vis.append('g').attr('class', 'chart1')
//       .attr('transform','translate(' + geom.chart_left + ',' + geom.chart_top + ')');
//     var overlay = chart.append('g').attr('class', 'element').attr('class', 'overlay');
//     var zoom = d3.zoom().scaleExtent([1/3,3]);
//     var zoomNode = overlay.append('rect').attr('class', 'overlay')
//       .attr('x', geom.inner_left).attr('y', geom.inner_top)
//       .attr('width', geom.inner_rawWidth).attr('height', geom.inner_rawHeight)
//       .style('cursor', 'move').call(zoom)
//       .node();
//     zoomNode.__zoom = d3.zoomIdentity;
//     chart.append('rect').attr('class', 'background').attr('width', geom.chart_right-geom.chart_left).attr('height', geom.chart_bottom-geom.chart_top);
//     var interior = chart.append('g').attr('class', 'interior zoomNone')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')')
//       .attr('clip-path', 'url(#clip_visidf281a110-9b19-4cb3-b18e-1e11ea7d3f38_chart1_inner)');
//     interior.append('rect').attr('class', 'inner').attr('width', geom.inner_width).attr('height', geom.inner_height);
//     var gridGroup = interior.append('g').attr('class', 'grid');
//     var axes = chart.append('g').attr('class', 'axis')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')');
//     vis.append('clipPath').attr('id', 'clip_visidf281a110-9b19-4cb3-b18e-1e11ea7d3f38_chart1_inner').append('rect')
//       .attr('x', 0).attr('y', 0)
//       .attr('width', geom.inner_rawWidth+1).attr('height', geom.inner_rawHeight+1);
//
//     // Scales //////////////////////////////////////////////////////////////////////////////////////
//
//     var scale_x = d3.scalePoint().padding(0.5)
//       .domain(['1Q14', '2Q14', '3Q14', '4Q14', '1Q15', '2Q15', '3Q15', '4Q15', '1Q16', '2Q16', '3Q16', '4Q16'])
//       .range([0, geom.inner_width]);
//     var scale_inner = d3.scaleLinear().domain([0,1])
//       .range([-0.5, 0.5]);
//     var scale_y = d3.scaleLinear().domain([0, 30.000003])
//       .range([geom.inner_height, 0]);
//     var base_scales = [scale_x, scale_y];                           // untransformed original scales
//
//     // Axes ////////////////////////////////////////////////////////////////////////////////////////
//
//     axes.append('g').attr('class', 'x axis')
//       .attr('transform','translate(0,' + geom.inner_rawHeight + ')')
//       .attr('clip-path', 'url(#clip_visidf281a110-9b19-4cb3-b18e-1e11ea7d3f38_chart1_haxis)');
//     vis.append('clipPath').attr('id', 'clip_visidf281a110-9b19-4cb3-b18e-1e11ea7d3f38_chart1_haxis').append('polyline')
//       .attr('points', '-1,-1000, -1,-1 -5,5, -1000,5, -100,1000, 10000,1000 10000,-1000');
//     axes.select('g.axis.x').append('text').attr('class', 'title').text('Time').style('text-anchor', 'middle')
//       .attr('x',geom.inner_rawWidth/2)
//       .attr('y', geom.inner_bottom - 2.0).attr('dy','-0.27em');
//     axes.append('g').attr('class', 'y axis')
//       .attr('clip-path', 'url(#clip_visidf281a110-9b19-4cb3-b18e-1e11ea7d3f38_chart1_vaxis)');
//     vis.append('clipPath').attr('id', 'clip_visidf281a110-9b19-4cb3-b18e-1e11ea7d3f38_chart1_vaxis').append('polyline')
//       .attr('points', '-1000,-10000, 10000,-10000, 10000,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+5) + ', -1000,' + (geom.inner_rawHeight+5) );
//     axes.select('g.axis.y').append('text').attr('class', 'title').text('Churn Rate').style('text-anchor', 'middle')
//       .attr('x',-geom.inner_rawHeight/2)
//       .attr('y', 4-geom.inner_left).attr('dy', '0.7em').attr('transform', 'rotate(270)');
//
//     var axis_bottom = d3.axisBottom(scale_x).ticks(Math.min(10, Math.round(geom.inner_width / 42.0)));
//     var axis_left = d3.axisLeft(scale_y).ticks(Math.min(10, Math.round(geom.inner_width / 20)));
//
//     function buildAxes(time) {
//       axis_bottom.tickValues(BrunelD3.filterTicks(scale_x))
//       var axis_x = axes.select('g.axis.x');
//       BrunelD3.transition(axis_x, time).call(axis_bottom.scale(scale_x));
//       var axis_y = axes.select('g.axis.y');
//       BrunelD3.transition(axis_y, time).call(axis_left.scale(scale_y));
//       BrunelD3.makeGrid(gridGroup, scale_y, geom.inner_width, false );
//     }
//     zoom.on('zoom', function(t, time) {
//         t = t ||BrunelD3.restrictZoom(d3.event.transform, geom, this);
//         scale_y = t.rescaleY(base_scales[1]);
//         zoomNode.__zoom = t;
//         interior.attr('class', 'interior ' + BrunelD3.zoomLabel(t.k));;
//         build(time || -1);
//     });
//
//     // Define element #1 ///////////////////////////////////////////////////////////////////////////
//
//     elements[0] = function() {
//       var original, processed,                           // data sets passed in and then transformed
//         element, data,                                 // brunel element information and brunel data
//         selection, merged;                                      // d3 selection and merged selection
//       var elementGroup = interior.append('g').attr('class', 'element1'),
//         main = elem

// %% [markdown]
// ## 1.3 Load the detailed customer information

// %%
val churnData = spark.read.format("jdbc").options(Map("driver" -> "com.ibm.db2.jcc.DB2Driver",
      "url" -> "jdbc:db2://9.125.72.72:430/LOCDB11", "user" -> "TUSER01",
      "password" -> "C6DESHOP", "dbtable" -> "MLZ.CHURN_CUST_SUM")).load() 
churnData.show(5, false)
churnData.count()
// Out:
// +----------+---+---+---------+----------+-------+--------+-----+--------+------------+-------+----------+---------+-----+----------------+---------+-----------+
// |CUST_ID   |SEX|AGE|EDUCATION|INVESTMENT|INCOME |ACTIVITY|CHURN|YRLY_AMT|AVG_DAILY_TX|YRLY_TX|AVG_TX_AMT|NEGTWEETS|STATE|EDUCATION_GROUP |TwitterID|CHURN_LABEL|
// +----------+---+---+---------+----------+-------+--------+-----+--------+------------+-------+----------+---------+-----+----------------+---------+-----------+
// |1009530860|F  |84 |2        |114368    |3852862|5       |0    |700259.0|0.917808    |335    |2090.32   |3        |TX   |Bachelors degree|0        |0          |
// |1009544000|F  |44 |2        |90298     |3849843|1       |0    |726977.0|0.950685    |347    |2095.04   |2        |CA   |Bachelors degree|0        |0          |
// |1009534260|F  |23 |2        |94881     |3217364|1       |1    |579084.0|0.920548    |336    |1723.46   |5        |CA   |Bachelors degree|0        |1          |
// |1009574010|F  |24 |2        |112099    |2438218|4       |1    |470964.0|0.994521    |363    |1297.4199 |2        |WA   |Bachelors degree|0        |1          |
// |1009578620|F  |67 |5        |84638     |2428245|3       |0    |446615.0|0.917808    |335    |1333.1799 |3        |CT   |Doctorate       |0        |0          |
// +----------+---+---+---------+----------+-------+--------+-----+--------+------------+-------+----------+---------+-----+----------------+---------+-----------+
// only showing top 5 rows
// 6001

// %% [markdown]
// ## 1.4 Drawing with the state as the X axis, the income for the vertical

// %%
%%brunel data('churnData') x(STATE) y(INCOME) mean(INCOME) bar tooltip(#all) sort(INCOME:ascending) tooltip(#all) axes(x:'State', y:'Income':grid) 
:: width=800, height=500
// Out:
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/brunel.2.3.css" charset="utf-8">
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/sumoselect.css" charset="utf-8">
//          <style>  </style>
//          <div id="controlsId84549b13-d4b6-4ad8-8b05-ef42bc9b3cd7" class="brunel"/>
// <svg id="visid3e19dfd2-1073-49f9-a9e2-493281497a99" width="800" height="500"></svg>
//
// <script>
// require.config({
//             waitSeconds: 60,
//             paths: {
//                 'd3': '//cdnjs.cloudflare.com/ajax/libs/d3/4.2.1/d3.min',
//                 'topojson' : '//cdnjs.cloudflare.com/ajax/libs/topojson/1.6.20/topojson.min',
//                 'brunel' : 'https://brunelvis.org/js/brunel.2.3.min',
//                 'brunelControls' : 'https://brunelvis.org/js/brunel.controls.2.3.min'
//             },
//
//             shim: {
//                'brunel' : {
//                     exports: 'BrunelD3',
//                     deps: ['d3', 'topojson'],
//                     init: function() {
//                        return {
//                          BrunelD3 : BrunelD3,
//                          BrunelData : BrunelData
//                       }
//                     }
//                 },
//                'brunelControls' : {
//                     exports: 'BrunelEventHandlers',
//                     init: function() {
//                        return {
//                          BrunelEventHandlers: BrunelEventHandlers,
//                          BrunelJQueryControlFactory: BrunelJQueryControlFactory
//                       }
//                     }
//                 }
//
//             }
//
//         });
//
//         require(["d3"], function(d3) {
//         require(["brunel", "brunelControls"], function(brunel, brunelControls) {
//
//             function  BrunelVis(visId) {
//   "use strict";                                                                       // strict mode
//   var datasets = [],                                      // array of datasets for the original data
//       pre = function(d, i) { return d },                         // default pre-process does nothing
//       post = function(d, i) { return d },                       // default post-process does nothing
//       transitionTime = 200,                                        // transition time for animations
//       charts = [],                                                       // the charts in the system
//       vis = d3.select('#' + visId).attr('class', 'brunel');                     // the SVG container
//
//   BrunelD3.addDefinitions(vis);                                   // ensure standard symbols present
//
//   // Define chart #1 in the visualization //////////////////////////////////////////////////////////
//
//   charts[0] = function(parentNode, filterRows) {
//     var geom = BrunelD3.geometry(parentNode || vis.node(), 0, 0, 1, 1, 5, 65, 46, 3),
//       elements = [];                                              // array of elements in this chart
//
//     // Define groups for the chart parts ///////////////////////////////////////////////////////////
//
//     var chart =  vis.append('g').attr('class', 'chart1')
//       .attr('transform','translate(' + geom.chart_left + ',' + geom.chart_top + ')');
//     var overlay = chart.append('g').attr('class', 'element').attr('class', 'overlay');
//     var zoom = d3.zoom().scaleExtent([1/3,3]);
//     var zoomNode = overlay.append('rect').attr('class', 'overlay')
//       .attr('x', geom.inner_left).attr('y', geom.inner_top)
//       .attr('width', geom.inner_rawWidth).attr('height', geom.inner_rawHeight)
//       .style('cursor', 'move').call(zoom)
//       .node();
//     zoomNode.__zoom = d3.zoomIdentity;
//     chart.append('rect').attr('class', 'background').attr('width', geom.chart_right-geom.chart_left).attr('height', geom.chart_bottom-geom.chart_top);
//     var interior = chart.append('g').attr('class', 'interior zoomNone')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')')
//       .attr('clip-path', 'url(#clip_visid3e19dfd2-1073-49f9-a9e2-493281497a99_chart1_inner)');
//     interior.append('rect').attr('class', 'inner').attr('width', geom.inner_width).attr('height', geom.inner_height);
//     var gridGroup = interior.append('g').attr('class', 'grid');
//     var axes = chart.append('g').attr('class', 'axis')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')');
//     vis.append('clipPath').attr('id', 'clip_visid3e19dfd2-1073-49f9-a9e2-493281497a99_chart1_inner').append('rect')
//       .attr('x', 0).attr('y', 0)
//       .attr('width', geom.inner_rawWidth+1).attr('height', geom.inner_rawHeight+1);
//
//     // Scales //////////////////////////////////////////////////////////////////////////////////////
//
//     var scale_x = d3.scalePoint().padding(0.5)
//       .domain(['NC', 'MN', 'VA', 'AL', 'AZ', 'AR', 'NM', 'LA', 'DC', 'UT', 'ND', 'NH', 'MO', 'MS', 'TN', 'OH', 'FL', 'WI', 'MA', 'MD', 'SD', 'KY', 'GA', 'DE', 'OK', 'WV', 'CO', 'MI', 'IL', 'MT', 'NJ', 'IA', 'IN', 'SC', 'OR', 'ID', 'PA', 'ME', 'AK', 'KS', 'NE', 'WY', 'NV', 'RI', 'VT', 'WA', 'CA', 'NY', 'TX', 'CT'])
//       .range([0, geom.inner_width]);
//     var scale_inner = d3.scaleLinear().domain([0,1])
//       .range([-0.5, 0.5]);
//     var scale_y = d3.scaleSqrt().domain([0, 120000.01])
//       .range([geom.inner_height, 0]);
//     var base_scales = [scale_x, scale_y];                           // untransformed original scales
//
//     // Axes ////////////////////////////////////////////////////////////////////////////////////////
//
//     axes.append('g').attr('class', 'x axis')
//       .attr('transform','translate(0,' + geom.inner_rawHeight + ')')
//       .attr('clip-path', 'url(#clip_visid3e19dfd2-1073-49f9-a9e2-493281497a99_chart1_haxis)');
//     vis.append('clipPath').attr('id', 'clip_visid3e19dfd2-1073-49f9-a9e2-493281497a99_chart1_haxis').append('polyline')
//       .attr('points', '-1,-1000, -1,-1 -5,5, -1000,5, -100,1000, 10000,1000 10000,-1000');
//     axes.select('g.axis.x').append('text').attr('class', 'title').text('State').style('text-anchor', 'middle')
//       .attr('x',geom.inner_rawWidth/2)
//       .attr('y', geom.inner_bottom - 2.0).attr('dy','-0.27em');
//     axes.append('g').attr('class', 'y axis')
//       .attr('clip-path', 'url(#clip_visid3e19dfd2-1073-49f9-a9e2-493281497a99_chart1_vaxis)');
//     vis.append('clipPath').attr('id', 'clip_visid3e19dfd2-1073-49f9-a9e2-493281497a99_chart1_vaxis').append('polyline')
//       .attr('points', '-1000,-10000, 10000,-10000, 10000,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+5) + ', -1000,' + (geom.inner_rawHeight+5) );
//     axes.select('g.axis.y').append('text').attr('class', 'title').text('Income').style('text-anchor', 'middle')
//       .attr('x',-geom.inner_rawHeight/2)
//       .attr('y', 4-geom.inner_left).attr('dy', '0.7em').attr('transform', 'rotate(270)');
//
//     var axis_bottom = d3.axisBottom(scale_x).ticks(Math.min(10, Math.round(geom.inner_width / 25.5)));
//     var axis_left = d3.axisLeft(scale_y).ticks(Math.min(10, Math.round(geom.inner_width / 20)));
//
//     function buildAxes(time) {
//       axis_bottom.tickValues(BrunelD3.filterTicks(scale_x))
//       var axis_x = axes.select('g.axis.x');
//       BrunelD3.transition(axis_x, time).call(axis_bottom.scale(scale_x)).selectAll('.tick text')
//         .attr('transform', function() {
//           var v = this.getComputedTextLength() / Math.sqrt(2)/2;
//           return 'translate(-' + (v+6) + ',' + v + ') rotate(-45)'
//       });
//       var axis_y = axes.select('g.axis.y');
//       BrunelD3.transition(axis_y, time).call(axis_left.scale(scale_y));
//       BrunelD3.makeGrid(gridGroup, scale_y, geom.inner_width, false );
//     }
//     zoom.on('zoom', function(t, time) {
//         t = t ||BrunelD3.restrictZoom(d3.event.transform, geom, this);
//         scale_y = t.rescaleY(base_scales[1]);
//         zoomNode.__zoom = t;
//         interior.attr('class', 'interior ' + BrunelD3.zoomLabel(t.k));;
//         build(time || -1);
//     });
//
//     // Define element #1 ///////////////////////////////////////////////////////////////////////////
//
//     elements[0] = func

// %% [markdown]
// ## 1.5 Drawing map with the income as the lable

// %%
%%brunel data('churnData') map key(STATE) x(STATE) color(INCOME) mean(INCOME) label(STATE) tooltip(#all) :: width=800, height=500
// Out:
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/brunel.2.3.css" charset="utf-8">
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/sumoselect.css" charset="utf-8">
//          <style>  </style>
//          <div id="controlsIdb40c2880-776d-4d86-991a-47f86747d706" class="brunel"/>
// <svg id="visidb34b62ff-a53e-400d-ac8d-6b6f999c5eff" width="800" height="500"></svg>
//
// <script>
// require.config({
//             waitSeconds: 60,
//             paths: {
//                 'd3': '//cdnjs.cloudflare.com/ajax/libs/d3/4.2.1/d3.min',
//                 'topojson' : '//cdnjs.cloudflare.com/ajax/libs/topojson/1.6.20/topojson.min',
//                 'brunel' : 'https://brunelvis.org/js/brunel.2.3.min',
//                 'brunelControls' : 'https://brunelvis.org/js/brunel.controls.2.3.min'
//             },
//
//             shim: {
//                'brunel' : {
//                     exports: 'BrunelD3',
//                     deps: ['d3', 'topojson'],
//                     init: function() {
//                        return {
//                          BrunelD3 : BrunelD3,
//                          BrunelData : BrunelData
//                       }
//                     }
//                 },
//                'brunelControls' : {
//                     exports: 'BrunelEventHandlers',
//                     init: function() {
//                        return {
//                          BrunelEventHandlers: BrunelEventHandlers,
//                          BrunelJQueryControlFactory: BrunelJQueryControlFactory
//                       }
//                     }
//                 }
//
//             }
//
//         });
//
//         require(["d3"], function(d3) {
//         require(["brunel", "brunelControls"], function(brunel, brunelControls) {
//
//             function  BrunelVis(visId) {
//   "use strict";                                                                       // strict mode
//   var datasets = [],                                      // array of datasets for the original data
//       pre = function(d, i) { return d },                         // default pre-process does nothing
//       post = function(d, i) { return d },                       // default post-process does nothing
//       transitionTime = 200,                                        // transition time for animations
//       charts = [],                                                       // the charts in the system
//       vis = d3.select('#' + visId).attr('class', 'brunel');                     // the SVG container
//
//   BrunelD3.addDefinitions(vis);                                   // ensure standard symbols present
//
//   // Define chart #1 in the visualization //////////////////////////////////////////////////////////
//
//   charts[0] = function(parentNode, filterRows) {
//     var geom = BrunelD3.geometry(parentNode || vis.node(), 0, 0, 1, 1, 0, 0, 0, 90),
//       elements = [];                                              // array of elements in this chart
//
//     // Define groups for the chart parts ///////////////////////////////////////////////////////////
//
//     var chart =  vis.append('g').attr('class', 'chart1')
//       .attr('transform','translate(' + geom.chart_left + ',' + geom.chart_top + ')');
//     var overlay = chart.append('g').attr('class', 'element').attr('class', 'overlay');
//     var zoom = d3.zoom().scaleExtent([1/5,5]);
//     var zoomNode = overlay.append('rect').attr('class', 'overlay')
//       .attr('x', geom.inner_left).attr('y', geom.inner_top)
//       .attr('width', geom.inner_rawWidth).attr('height', geom.inner_rawHeight)
//       .style('cursor', 'move').call(zoom)
//       .node();
//     zoomNode.__zoom = d3.zoomIdentity;
//     chart.append('rect').attr('class', 'background').attr('width', geom.chart_right-geom.chart_left).attr('height', geom.chart_bottom-geom.chart_top);
//     var interior = chart.append('g').attr('class', 'interior zoomNone')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')')
//       .attr('clip-path', 'url(#clip_visidb34b62ff-a53e-400d-ac8d-6b6f999c5eff_chart1_inner)');
//     interior.append('rect').attr('class', 'inner').attr('width', geom.inner_width).attr('height', geom.inner_height);
//     var gridGroup = interior.append('g').attr('class', 'grid');
//     var legends = chart.append('g').attr('class', 'legend')
//       .attr('transform','translate(' + (geom.chart_right-geom.chart_left - 3) + ',' + 0 + ')');
//     vis.append('clipPath').attr('id', 'clip_visidb34b62ff-a53e-400d-ac8d-6b6f999c5eff_chart1_inner').append('rect')
//       .attr('x', 0).attr('y', 0)
//       .attr('width', geom.inner_rawWidth+1).attr('height', geom.inner_rawHeight+1);
//
//     // Projection //////////////////////////////////////////////////////////////////////////////////
//
//     var base = d3.geoAlbersUsa()
//       .scale(Math.min(geom.inner_width/0.96, geom.inner_height/0.48))
//       .translate([geom.inner_width/2, geom.inner_height/2])
//     function projection(p) {
//         var q = base(p), t = d3.zoomTransform(zoomNode);
//         return q ? [t.k*q[0]+t.x, t.k*q[1]+t.y] : null;
//     };
//     function project_center(v) { return (v ? projection([v.c, v.d]) : null) || [-9e6, -9e6] };
//     var path = d3.geoPath().projection(BrunelD3.geoStream(projection));
//     var scale_x = d3.scaleLinear(), scale_y = d3.scaleLinear();
//     var base_scales = [scale_x, scale_y];                           // untransformed original scales
//     zoom.on('zoom', function(t, time) {
//         t = t || d3.event.transform;
//         zoomNode.__zoom = t;
//         interior.attr('class', 'interior ' + BrunelD3.zoomLabel(t.k));;
//         build(time || -1);
//     });
//
//     // Define element #1 ///////////////////////////////////////////////////////////////////////////
//
//     elements[0] = function() {
//       var original, processed,                           // data sets passed in and then transformed
//         element, data,                                 // brunel element information and brunel data
//         selection, merged;                                      // d3 selection and merged selection
//       var elementGroup = interior.append('g').attr('class', 'element1'),
//         main = elementGroup.append('g').attr('class', 'main'),
//         labels = BrunelD3.undoTransform(elementGroup.append('g').attr('class', 'labels').attr('aria-hidden', 'true'), elementGroup);
//
//       function makeData() {
//         original = datasets[0];
//         if (filterRows) original = original.retainRows(filterRows);
//         processed = pre(original, 0)
//           .summarize('INCOME=INCOME:mean; STATE=STATE:base');
//         processed = post(processed, 0);
//         var f0 = processed.field('STATE'),
//           f1 = processed.field('INCOME'),
//           f2 = processed.field('#row'),
//           f3 = processed.field('#selection');
//         var keyFunc = function(d) { return f0.value(d) };
//         data = {
//           STATE:        function(d) { return f0.value(d.row) },
//           INCOME:       function(d) { return f1.value(d.row) },
//           $row:         function(d) { return f2.value(d.row) },
//           $selection:   function(d) { return f3.value(d.row) },
//           STATE_f:      function(d) { return f0.valueFormatted(d.row) },
//           INCOME_f:     function(d) { return f1.valueFormatted(d.row) },
//           $row_f:       function(d) { return f2.valueFormatted(d.row) },
//           $selection_f: function(d) { return f3.valueFormatted(d.row) },
//           _split:       function(d) { return f1.value(d.row) },
//           _key:         keyFunc,
//           _rows:        BrunelD3.makeRowsWithKeys(keyFunc, processed.rowCount())
//         };
//       }
//       // Aesthetic Functions
//       var scale_color = d3.scaleSqrt().domain([24154.512, 31610.162, 40067.116, 49525.373, 59984.934, 71445.799, 83907.967, 97371.439, 111836.21])
//         .interpolate(d3.interpolateHcl)
//         .range([ '#045a8d', '#2b8cbe', '#74a9cf', '#bdc9e1', '#f8efe8', '#fef0d9',
//           '#fdcc8a', '#fc8d59', '#e34a33']);
//       var color = function(d) { return scale_color(data.INCOME(d)) };
//       legends._legend = legends._legend || { title: ['Mean(INCOME)'],
//         ticks: [120000,

// %%
%%brunel data('churnData') 
         x(AGE) y(#count:linear) color(CHURN_LABEL) bin(AGE) interaction(select) stack bar tooltip(#all) filter(CHURN_LABEL) legends(none) |
         x(AVG_DAILY_TX) y(#count:linear) color(CHURN_LABEL) opacity(#selection) bin(AVG_DAILY_TX) stack bar tooltip(#all) axes(x:10:'AVG DAILY TX', y)|
         x(AVG_TX_AMT) y(#count:linear) color(CHURN_LABEL) opacity(#selection) bin(AVG_TX_AMT) stack bar tooltip(#all)  axes(x,y) legends(none) |
        x(INCOME) y(#count:linear) color(CHURN_LABEL) opacity(#selection) bin(INCOME) stack bar tooltip(#all) tooltip(#all) axes(x,y) legends(none)
:: width=800, height=600

// %%
%%brunel data('churnData')
         x(SEX) y(#count:linear) color(CHURN_LABEL) stack bar tooltip(#all) sort(SEX) interaction(select) filter(CHURN_LABEL) axes(x:'GENDER', y) legends(none) |
         x(ACTIVITY) y(#count:linear) color(CHURN_LABEL) stack bar tooltip(#all) sort(ACTIVITY) opacity(#selection)  | 
         x(EDUCATION_GROUP) y(#count:linear) color(CHURN_LABEL) stack bar tooltip(#all) sort(#count) opacity(#selection)  axes(x:'',y) legends(none)
:: width=900, height=600

// %%
%%brunel data('churnData') map key(STATE) x(STATE) color(CHURN) mean(CHURN) label(STATE) tooltip(#all) :: width=800, height=500

// %% [markdown]
// # 2. training customer churn classifier

// %%
//import libraries
import org.apache.spark.ml.feature.{StringIndexer,VectorAssembler}
import org.apache.spark.ml.classification.LogisticRegression
import org.apache.spark.ml.evaluation.BinaryClassificationEvaluator
import org.apache.spark.ml.Pipeline
import org.apache.spark.ml.tuning.{CrossValidator,ParamGridBuilder}

// %% [markdown]
//  ## 2.2 Split the data into training and test data

// %%
val Array(training, test) = churnData.randomSplit(Array(0.8, 0.2), seed = 11L)
println("The number of training data is ",training.count())
println("The number of test data is ",test.count())
// Out:
// (The number of training data is ,4884)
// (The number of test data is ,1117)

// %%
val spamData = spark.read.format("jdbc").options(Map("driver" -> "com.ibm.db2.jcc.DB2Driver",
      "url" -> "jdbc:db2://9.125.72.72:430/LOCDB11", "user" -> "TUSER01",
      "password" -> "C6DESHOP", "dbtable" -> "MLZ.SPAMEMAIL")).load()   
spamData.cache()
spamData.printSchema()
spamData.show(5)
spamData.count()
// Out:
// root
//  |-- email_id: long (nullable = true)
//  |-- text: string (nullable = true)
//  |-- label: integer (nullable = true)
//
// +--------+--------------------+-----+
// |email_id|                text|label|
// +--------+--------------------+-----+
// |       1|One of a kind Mon...|    0|
// |      10|Re: What to choos...|    1|
// |     100|Strictly Private....|    0|
// |    1000|Re: Flash is open...|    1|
// |    1001|Re: Alsa/Redhat 8...|    1|
// +--------+--------------------+-----+
// only showing top 5 rows
// 2500

// %% [markdown]
// ## 2.3 Transform the string type to int , and select feature

// %%
//Feature definition
val genderIndexer = new StringIndexer().setInputCol("SEX").setOutputCol("gender_code")
val stateIndexer = new StringIndexer().setInputCol("STATE").setOutputCol("state_code")
val labelIndexer = new StringIndexer().setInputCol("CHURN").setOutputCol("label")

val featuresAssembler = new VectorAssembler().setInputCols(Array("AGE", 
                                                         "ACTIVITY", 
                                                         "EDUCATION", 
                                                         "NEGTWEETS" ,
                                                         "INCOME",
                                                         "gender_code",
                                                         "state_code")).setOutputCol("features")

// %% [markdown]
// ## 2.4 Use the logical regression algorithm, build Pipeline and cross-validate

// %%
//Select model automatically in candidate algorithm - Logistic Regression, SVM or Decision Tree?
val lr = new LogisticRegression().setRegParam(0.01).setLabelCol("label").setFeaturesCol("features")
val pipeline =new Pipeline().setStages(Array(labelIndexer, genderIndexer, stateIndexer, featuresAssembler,lr))
val auc_eval = new BinaryClassificationEvaluator()
val grid = new ParamGridBuilder().addGrid(lr.regParam, Array(1e-3, 1e-2)).addGrid(lr.elasticNetParam,Array(0.25, 0.0)).build()
val cross_val = new CrossValidator().setEstimator(pipeline).setEvaluator(auc_eval).setEstimatorParamMaps(grid).setNumFolds(3)

// %% [markdown]
// ## 2.5 Training model and  predict the test data

// %%
val pipeline_model = cross_val.fit(training)
val trainResult=pipeline_model.transform(test)

// %%
trainResult.printSchema()
// Out:
// root
//  |-- CUST_ID: integer (nullable = true)
//  |-- SEX: string (nullable = true)
//  |-- AGE: integer (nullable = true)
//  |-- EDUCATION: integer (nullable = true)
//  |-- INVESTMENT: integer (nullable = true)
//  |-- INCOME: integer (nullable = true)
//  |-- ACTIVITY: integer (nullable = true)
//  |-- CHURN: integer (nullable = true)
//  |-- YRLY_AMT: double (nullable = true)
//  |-- AVG_DAILY_TX: double (nullable = true)
//  |-- YRLY_TX: integer (nullable = true)
//  |-- AVG_TX_AMT: double (nullable = true)
//  |-- NEGTWEETS: integer (nullable = true)
//  |-- STATE: string (nullable = true)
//  |-- EDUCATION_GROUP: string (nullable = true)
//  |-- TwitterID: integer (nullable = true)
//  |-- CHURN_LABEL: string (nullable = true)
//  |-- label: double (nullable = true)
//  |-- gender_code: double (nullable = true)
//  |-- state_code: double (nullable = true)
//  |-- features: vector (nullable = true)
//  |-- rawPrediction: vector (nullable = true)
//  |-- probability: vector (nullable = true)
//  |-- prediction: double (nullable = true)

// %% [markdown]
// ## 2.6 Evaluate the model and draw the ROC curve

// %%
import org.apache.spark.mllib.evaluation.BinaryClassificationMetrics
val testingResultScores = trainResult.select("prediction","label").rdd.map(r => (r(0).asInstanceOf[Double], r(1) .asInstanceOf[Double]))
val bc = new BinaryClassificationMetrics(testingResultScores)
val roc = bc.roc

// %%
testingResultScores
// Out:
// MapPartitionsRDD[1574] at map at <console>:53

// %%
print( bc.roc())
// Out:
// UnionRDD[1599] at UnionRDD at BinaryClassificationMetrics.scala:89

// %%
val rocDF = spark.createDataFrame(roc).
                    withColumnRenamed("_1", "FPR").
                    withColumnRenamed("_2", "TPR")
rocDF.show()
// Out:
// +--------------------+------------------+
// |                 FPR|               TPR|
// +--------------------+------------------+
// |                 0.0|               0.0|
// |0.004813477737665...|0.9545454545454546|
// |                 1.0|               1.0|
// |                 1.0|               1.0|
// +--------------------+------------------+

// %%
%%brunel data('rocDF') x(FPR) y(TPR) line tooltip(#all) axes(x:'False Positive Rate':grid, y:'True Positive Rate':grid)
// Out:
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/brunel.2.3.css" charset="utf-8">
//          <link rel="stylesheet" type="text/css" href="https://brunelvis.org/js/sumoselect.css" charset="utf-8">
//          <style>  </style>
//          <div id="controlsId5dac2192-f245-4f68-831f-50904313dca9" class="brunel"/>
// <svg id="visidd3f7bb1f-1be9-4d31-b6ad-f2b8c0c5d9d4" width="500" height="400"></svg>
//
// <script>
// require.config({
//             waitSeconds: 60,
//             paths: {
//                 'd3': '//cdnjs.cloudflare.com/ajax/libs/d3/4.2.1/d3.min',
//                 'topojson' : '//cdnjs.cloudflare.com/ajax/libs/topojson/1.6.20/topojson.min',
//                 'brunel' : 'https://brunelvis.org/js/brunel.2.3.min',
//                 'brunelControls' : 'https://brunelvis.org/js/brunel.controls.2.3.min'
//             },
//
//             shim: {
//                'brunel' : {
//                     exports: 'BrunelD3',
//                     deps: ['d3', 'topojson'],
//                     init: function() {
//                        return {
//                          BrunelD3 : BrunelD3,
//                          BrunelData : BrunelData
//                       }
//                     }
//                 },
//                'brunelControls' : {
//                     exports: 'BrunelEventHandlers',
//                     init: function() {
//                        return {
//                          BrunelEventHandlers: BrunelEventHandlers,
//                          BrunelJQueryControlFactory: BrunelJQueryControlFactory
//                       }
//                     }
//                 }
//
//             }
//
//         });
//
//         require(["d3"], function(d3) {
//         require(["brunel", "brunelControls"], function(brunel, brunelControls) {
//
//             function  BrunelVis(visId) {
//   "use strict";                                                                       // strict mode
//   var datasets = [],                                      // array of datasets for the original data
//       pre = function(d, i) { return d },                         // default pre-process does nothing
//       post = function(d, i) { return d },                       // default post-process does nothing
//       transitionTime = 200,                                        // transition time for animations
//       charts = [],                                                       // the charts in the system
//       vis = d3.select('#' + visId).attr('class', 'brunel');                     // the SVG container
//
//   BrunelD3.addDefinitions(vis);                                   // ensure standard symbols present
//
//   // Define chart #1 in the visualization //////////////////////////////////////////////////////////
//
//   charts[0] = function(parentNode, filterRows) {
//     var geom = BrunelD3.geometry(parentNode || vis.node(), 0, 0, 1, 1, 5, 43, 37, 13),
//       elements = [];                                              // array of elements in this chart
//
//     // Define groups for the chart parts ///////////////////////////////////////////////////////////
//
//     var chart =  vis.append('g').attr('class', 'chart1')
//       .attr('transform','translate(' + geom.chart_left + ',' + geom.chart_top + ')');
//     var overlay = chart.append('g').attr('class', 'element').attr('class', 'overlay');
//     var zoom = d3.zoom().scaleExtent([1/3,3]);
//     var zoomNode = overlay.append('rect').attr('class', 'overlay')
//       .attr('x', geom.inner_left).attr('y', geom.inner_top)
//       .attr('width', geom.inner_rawWidth).attr('height', geom.inner_rawHeight)
//       .style('cursor', 'move').call(zoom)
//       .node();
//     zoomNode.__zoom = d3.zoomIdentity;
//     chart.append('rect').attr('class', 'background').attr('width', geom.chart_right-geom.chart_left).attr('height', geom.chart_bottom-geom.chart_top);
//     var interior = chart.append('g').attr('class', 'interior zoomNone')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')')
//       .attr('clip-path', 'url(#clip_visidd3f7bb1f-1be9-4d31-b6ad-f2b8c0c5d9d4_chart1_inner)');
//     interior.append('rect').attr('class', 'inner').attr('width', geom.inner_width).attr('height', geom.inner_height);
//     var gridGroup = interior.append('g').attr('class', 'grid');
//     var axes = chart.append('g').attr('class', 'axis')
//       .attr('transform','translate(' + geom.inner_left + ',' + geom.inner_top + ')');
//     vis.append('clipPath').attr('id', 'clip_visidd3f7bb1f-1be9-4d31-b6ad-f2b8c0c5d9d4_chart1_inner').append('rect')
//       .attr('x', 0).attr('y', 0)
//       .attr('width', geom.inner_rawWidth+1).attr('height', geom.inner_rawHeight+1);
//
//     // Scales //////////////////////////////////////////////////////////////////////////////////////
//
//     var scale_x = d3.scaleLinear().domain([0, 1.0000001])
//       .range([0, geom.inner_width]);
//     var scale_inner = d3.scaleLinear().domain([0,1])
//       .range([-0.5, 0.5]);
//     var scale_y = d3.scaleLinear().domain([0, 1.0000001])
//       .range([geom.inner_height, 0]);
//     var base_scales = [scale_x, scale_y];                           // untransformed original scales
//
//     // Axes ////////////////////////////////////////////////////////////////////////////////////////
//
//     axes.append('g').attr('class', 'x axis')
//       .attr('transform','translate(0,' + geom.inner_rawHeight + ')')
//       .attr('clip-path', 'url(#clip_visidd3f7bb1f-1be9-4d31-b6ad-f2b8c0c5d9d4_chart1_haxis)');
//     vis.append('clipPath').attr('id', 'clip_visidd3f7bb1f-1be9-4d31-b6ad-f2b8c0c5d9d4_chart1_haxis').append('polyline')
//       .attr('points', '-1,-1000, -1,-1 -5,5, -1000,5, -100,1000, 10000,1000 10000,-1000');
//     axes.select('g.axis.x').append('text').attr('class', 'title').text('False Positive Rate').style('text-anchor', 'middle')
//       .attr('x',geom.inner_rawWidth/2)
//       .attr('y', geom.inner_bottom - 2.0).attr('dy','-0.27em');
//     axes.append('g').attr('class', 'y axis')
//       .attr('clip-path', 'url(#clip_visidd3f7bb1f-1be9-4d31-b6ad-f2b8c0c5d9d4_chart1_vaxis)');
//     vis.append('clipPath').attr('id', 'clip_visidd3f7bb1f-1be9-4d31-b6ad-f2b8c0c5d9d4_chart1_vaxis').append('polyline')
//       .attr('points', '-1000,-10000, 10000,-10000, 10000,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+1) + ', -1,' + (geom.inner_rawHeight+5) + ', -1000,' + (geom.inner_rawHeight+5) );
//     axes.select('g.axis.y').append('text').attr('class', 'title').text('True Positive Rate').style('text-anchor', 'middle')
//       .attr('x',-geom.inner_rawHeight/2)
//       .attr('y', 4-geom.inner_left).attr('dy', '0.7em').attr('transform', 'rotate(270)');
//
//     var axis_bottom = d3.axisBottom(scale_x).ticks(Math.min(10, Math.round(geom.inner_width / 33.0)));
//     var axis_left = d3.axisLeft(scale_y).ticks(Math.min(10, Math.round(geom.inner_width / 20)));
//
//     function buildAxes(time) {
//       var axis_x = axes.select('g.axis.x');
//       BrunelD3.transition(axis_x, time).call(axis_bottom.scale(scale_x));
//       var axis_y = axes.select('g.axis.y');
//       BrunelD3.transition(axis_y, time).call(axis_left.scale(scale_y));
//       BrunelD3.makeGrid(gridGroup, scale_x, geom.inner_height, true );
//       BrunelD3.makeGrid(gridGroup, scale_y, geom.inner_width, false );
//     }
//     zoom.on('zoom', function(t, time) {
//         t = t ||BrunelD3.restrictZoom(d3.event.transform, geom, this);
//         scale_x = t.rescaleX(base_scales[0]);
//         scale_y = t.rescaleY(base_scales[1]);
//         zoomNode.__zoom = t;
//         interior.attr('class', 'interior ' + BrunelD3.zoomLabel(t.k));;
//         build(time || -1);
//     });
//
//     // Define element #1 ///////////////////////////////////////////////////////////////////////////
//
//     elements[0] = function() {
//       var original, processed,                           // data sets passed in and then transformed
//         element, data,                                 // brunel element information and brunel data
//         selection, merged;                                      // d3 selection and merged selection
//       var elementGroup = interior.append('g').attr('class', 'element1'),
//         main = elementGroup.append('g')

// %%
case class Person(AGE:Int,ACTIVITY:Int,EDUCATION:Int,NEGTWEETS:Int,INCOME:Int,SEX:String,STATE:String)
val dataFrame=Seq(Person(40,1,3,4,200000,"M","TX"),Person(40,1,3,8,200000,"M","OR"))
val df = spark.createDataFrame(dataFrame)
df.show()
pipeline_model.transform(df).show()
// Out:
// +---+--------+---------+---------+------+---+-----+
// |AGE|ACTIVITY|EDUCATION|NEGTWEETS|INCOME|SEX|STATE|
// +---+--------+---------+---------+------+---+-----+
// | 40|       1|        3|        4|200000|  M|   TX|
// | 40|       1|        3|        8|200000|  M|   OR|
// +---+--------+---------+---------+------+---+-----+
//
// +---+--------+---------+---------+------+---+-----+-----------+----------+--------------------+--------------------+--------------------+----------+
// |AGE|ACTIVITY|EDUCATION|NEGTWEETS|INCOME|SEX|STATE|gender_code|state_code|            features|       rawPrediction|         probability|prediction|
// +---+--------+---------+---------+------+---+-----+-----------+----------+--------------------+--------------------+--------------------+----------+
// | 40|       1|        3|        4|200000|  M|   TX|        0.0|      27.0|[40.0,1.0,3.0,4.0...|[4.52523954313736...|[0.98928395807943...|       0.0|
// | 40|       1|        3|        8|200000|  M|   OR|        0.0|       5.0|[40.0,1.0,3.0,8.0...|[-3.5704582434082...|[0.02737260833349...|       1.0|
// +---+--------+---------+---------+------+---+-----+-----------+----------+--------------------+--------------------+--------------------+----------+
