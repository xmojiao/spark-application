# %%
import brunel

# %% [markdown]
# ## 美国50个州夏季和冬季的气温变化

# %%
# %brunel data('http://brunel.mybluemix.net/sample_data/US States.csv') bar x(Summer) y(Winter)
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %% [markdown]
# ## 每个区域的统计数量

# %%
# %brunel data('http://brunel.mybluemix.net/sample_data/US States.csv')  point x(Region) y(#count)
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %% [markdown]
# ## 计算每个区域的平均降雨量，并按照平均值排序。

# %%
# %brunel data('http://brunel.mybluemix.net/sample_data/US States.csv') bar x(Region) y(Rain) mean(Rain) sort(Rain)
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %% [markdown]
# ## 计算每个区域的平均降雨量，并按照平均值排序，并纵向显示。即颠倒上图的方向

# %%
# %brunel data('http://brunel.mybluemix.net/sample_data/US States.csv') bar x(Region) y(Rain) mean(Rain) sort(Rain) transpose
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %% [markdown]
# ## 每个区域内的总统投票：

# %%
# %brunel data('http://brunel.mybluemix.net/sample_data/US States.csv') bar x(Region, Presidential_Choice) y(#count) color(Presidential_Choice)
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %% [markdown]
# ## 在2005 - 2015年间，超过20岁的人失业率

# %%
# %brunel data('http://brunel.mybluemix.net/sample_data/Unemployment.csv') x(#row) y(Women, Men) color(#series) line tooltip(#all)
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %% [markdown]
# ## 以总统的选择为颜色标记，画出每个州的人口与收入图

# %%
# %brunel data('http://brunel.mybluemix.net/sample_data/US States.csv') x(Population) y(Income) color(Presidential_Choice)
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %% [markdown]
# ## 每月航班的总晚点次数

# %%
# %brunel data('http://brunel.mybluemix.net/sample_data/AirlineDelays.csv') x(Month) y(Late) sum(Late) line
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %% [markdown]
# ## 每月的航班总数 line,bar,area

# %%
# %brunel data('http://brunel.mybluemix.net/sample_data/AirlineDelays.csv') line x(Month) y(Count) sum(Count)
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %% [markdown]
# ## 按照总统的投票，将区域收入总额排在一个区域，stack选择使用衔接或者重叠方式

# %%
# %brunel data('http://brunel.mybluemix.net/sample_data/US States.csv') bar x(Region) y(Income) sum(Income) color(Presidential_Choice)stack
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %% [markdown]
# ## 每个游戏类别的游戏时间总计

# %%
# %brunel data('http://brunel.mybluemix.net/sample_data/BGG Top 2000 Games.csv') bubble x(Categories) color(Categories) size(PlayingTime) sum(PlayingTime)  label(Categories)
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %% [markdown]
# ## 美国地区平均降雨量

# %%
# %brunel data('sample:US States.csv') cloud color(Region) size(Rain)  mean(Rain) label(Region) legends(none)
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %% [markdown]
# ## 每个国家生产的威士忌

# %%
# %brunel data('http://brunel.mybluemix.net/sample_data/whiskey.csv') chord x(Country) y(Category) color(#count) tooltip(#all)
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %%
# %brunel data("sample:US States.csv") tree x(region, presidential_choice) color(income) mean(income) size(population:200) sum(population)
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %%
# %brunel data('sample:LesMis-Connections.csv') edge key(A, B) + data('sample:LesMis-Characters.csv') network key(ID) color(Main) label(Name:10) style("label-location:bottom") tooltip(name)
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
# ...

# %% [markdown]
# ## 美国地图，以年平均降雨量为颜色标记

# %%
# %brunel data('http://brunel.mybluemix.net/sample_data/US States.csv') map color(rain) key(state) label(state)
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %% [markdown]
# ## 显示欧洲和中国，是一个没有数据的背景地图，只是地理位置

# %%
# %brunel data('http://brunel.mybluemix.net/sample_data/US States.csv') map( 'china')
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %% [markdown]
# ## 拿破仑在俄罗斯的行军地图：道路宽度与军队的规模成正比

# %%
# %brunel data('http://brunel.mybluemix.net/sample_data/minard-troops.csv') map('russia', 'belarus', 'lithuania') + path x(long) y(lat) color(direction) size(survivors:400%) split(group) legends(none) + map(labels)
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...

# %% [markdown]
# ## 在每个区域的州的数量

# %%
# %brunel data('http://brunel.mybluemix.net/sample_data/US States.csv') stack polar  x("const") y(#count) color(region)  tooltip(#all)  label(region)  title("region")
# Out:
# <!--
#   ~ Copyright (c) 2015 IBM Corporation and others.
#   ~
#   ~ Licensed under the Apache License, Version 2.0 (the "License");
#   ~ You may not use this file except in compliance with the License.
#   ~ You may obtain a copy of the License at
#   ~
#   ~     http://www.apache.org/licenses/LICENSE-2.0
#   ~
#   ~ Unless required by applicable law or agreed to in writing, software
#   ~ distributed under the License is distributed on an "AS IS" BASIS,
#   ~ WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#   ~ See the License for the specific language governing permissions and
#   ~ limitations under the License.
#   -->
#
#
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/brunel.2.3.css">
# <link rel="stylesheet" type="text/css" href="/data/jupyter2/f05ef126-da5b-48cb-b604-4bddd6846000/nbextensions/brunel_ext/sumoselect.css">
#
# <style>
#
# </style>
#
# ...
